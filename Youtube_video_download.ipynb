# %% [markdown]
# <a href="https://colab.research.google.com/github/wuba16/PythonInDisguise/blob/main/Youtube_video_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yt-dlp

# %%
from __future__ import unicode_literals
import yt_dlp
url=input("Enter the Youtube video url : ")
youtube_opts={
    'formats' : 'bestvideo+bestaudio/best',
    'outtmpl' : '%(title)s.%(ext)s',
    'restrictfilenames' : True }
with yt_dlp.YoutubeDL(youtube_opts) as ydl:
    ydl.download([url])
print(" ..Download Complete! .. ")
